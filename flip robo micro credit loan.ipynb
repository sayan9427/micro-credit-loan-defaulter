# %%
import pandas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\sayan\OneDrive\Desktop\Data file.csv")
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
df.tail()
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 209588   1089.19                1.0                0.0              4048  ...
# 209589   1728.36                4.0                0.0               773  ...
# 209590   8893.20                3.0                0.0              1539  ...
# 209591    984.58                2.0               38.0               773  ...
# 209592    631.20               13.0                0.0              7526  ...
#
# ...

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
le=LabelEncoder()
list1=['msisdn','pcircle','pdate']
for i in list1:
    df[i]=le.fit_transform(df[i].astype(str))
df
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %%
df.plot(kind='box',subplots=True,layout=(10,20))
# Out:
# label                      AxesSubplot(0.125,0.816017;0.032563x0.0639831)
# msisdn                  AxesSubplot(0.164076,0.816017;0.032563x0.0639831)
# aon                     AxesSubplot(0.203151,0.816017;0.032563x0.0639831)
# daily_decr30            AxesSubplot(0.242227,0.816017;0.032563x0.0639831)
# daily_decr90            AxesSubplot(0.281303,0.816017;0.032563x0.0639831)
# rental30                AxesSubplot(0.320378,0.816017;0.032563x0.0639831)
# rental90                AxesSubplot(0.359454,0.816017;0.032563x0.0639831)
# last_rech_date_ma       AxesSubplot(0.398529,0.816017;0.032563x0.0639831)
# last_rech_date_da       AxesSubplot(0.437605,0.816017;0.032563x0.0639831)
# last_rech_amt_ma        AxesSubplot(0.476681,0.816017;0.032563x0.0639831)
# cnt_ma_rech30           AxesSubplot(0.515756,0.816017;0.032563x0.0639831)
# fr_ma_rech30            AxesSubplot(0.554832,0.816017;0.032563x0.0639831)
# sumamnt_ma_rech30       AxesSubplot(0.593908,0.816017;0.032563x0.0639831)
# ...

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %%
df.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177   93100.650179    8112.343445    5381.402289
# std         0.330519   53758.461427   75696.082531    9220.623400
# min         0.000000       0.000000     -48.000000     -93.012667
# 25%         1.000000   46506.000000     246.000000      42.440000
# 50%         1.000000   93073.000000     527.000000    1469.175667
# 75%         1.000000  139626.000000     982.000000    7244.000000
# max         1.000000  186242.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %%
df.drop(['pcircle'],axis=1,inplace=True)

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#            label    msisdn       aon  daily_decr30  daily_decr90  rental30  \
# 0       2.647896  0.984213  0.103577      0.252299      0.276346  0.573844
# 1       0.377658  0.915027  0.097764      0.731037      0.553380  0.231788
# 2       0.377658  1.106929  0.100102      0.432011      0.429033  0.416020
# 3       0.377658  0.205668  0.103986      0.581326      0.555125  0.587935
# 4       0.377658  1.603298  0.094660      0.567293      0.543274  0.369886
# ...          ...       ...       ...           ...           ...       ...
# 209588  0.377658  0.934453  0.101833      0.567157      0.543159  0.372140
# 209589  0.377658  1.583891  0.092969      0.579622      0.553686  0.223791
# 209590  0.377658  0.727434  0.093788      0.700790      0.533194  0.735567
# 209591  0.377658  0.340177  0.084289      0.770755      0.594558  0.529352
# 209592  0.377658  0.523869  0.086284      0.096744      0.141746  0.512620
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([16, 16, 33, ..., 29, 27, 31], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   40191   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1  142291   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   33594   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1  104157   241.0     21.228000     21.228000    159.42    159.42
# 4           1    6910   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...     ...           ...           ...       ...       ...
# 209588      1   42866   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  178248  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1   53995  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  111388  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  121263  1581.0   4489.362000   4534.820000    483.92    631.20
#
# ...

# %%
df_new.skew()
# Out:
# label                   -2.090315
# msisdn                  -0.000215
# aon                      0.957902
# daily_decr30             1.963747
# daily_decr90             2.077637
# rental30                 2.194889
# rental90                 2.244866
# last_rech_date_ma        3.099484
# last_rech_date_da       10.384887
# last_rech_amt_ma         2.125356
# cnt_ma_rech30            1.175157
# fr_ma_rech30             2.005139
# sumamnt_ma_rech30        1.634226
# medianamnt_ma_rech30     2.326312
# medianmarechprebal30    10.538891
# cnt_ma_rech90            1.321145
# fr_ma_rech90             1.985567
# sumamnt_ma_rech90        1.707309
# medianamnt_ma_rech90     2.373140
# medianmarechprebal90     3.692650
# cnt_da_rech30           50.760988
# fr_da_rech30             0.000000
# cnt_da_rech90            6.934340
# fr_da_rech90             0.000000
# cnt_loans30              1.465414
# amnt_loans30             1.441450
# maxamnt_loans30         53.470571
# ...

# %% [markdown]
# # removing skew

# %%
df_new['medianmarechprebal90']=np.sqrt(df['medianmarechprebal90'])

# %%
df_new['medianmarechprebal90'].skew()
# Out:
# -0.40531153356237987

# %%
df_new['cnt_da_rech90']=np.sqrt(df_new['cnt_da_rech90'])

# %%
df_new['fr_da_rech90']=np.sqrt(df_new['fr_da_rech90'])

# %%
df_new['last_rech_date_ma']=np.sqrt(df_new['last_rech_date_ma'])

# %%
df_new['last_rech_date_da']=np.sqrt(df_new['last_rech_date_da'])

# %%
df_new['medianmarechprebal30']=np.sqrt(df_new['medianmarechprebal30'])

# %%
df_new['cnt_da_rech30']=np.sqrt(df_new['cnt_da_rech30'])

# %%
df_new['maxamnt_loans30']=np.sqrt(df_new['maxamnt_loans30'])

# %%
df_new['cnt_loans90']=np.sqrt(df_new['cnt_loans90'])

# %%
df_new['fr_ma_rech30']=np.sqrt(df_new['fr_ma_rech30'])

# %%
df_new['payback30']=np.sqrt(df_new['payback30'])

# %%
df_new['payback90']=np.sqrt(df_new['payback90'])

# %%
df_new['medianamnt_loans90']=np.sqrt(df_new['medianamnt_loans90'])

# %%
df_new['medianamnt_loans30']=np.sqrt(df_new['medianamnt_loans30'])

# %%
df_new['daily_decr90']=np.sqrt(df_new['daily_decr90'])

# %%
df_new['rental30']=np.sqrt(df_new['rental30'])

# %%
df_new['rental90']=np.sqrt(df_new['rental90'])

# %%
df_new['last_rech_amt_ma ']=np.sqrt(df_new['last_rech_amt_ma'])

# %%
df_new['medianamnt_ma_rech90']=np.sqrt(df_new['medianamnt_ma_rech90'])

# %%
df_new['daily_decr30']=np.sqrt(df_new['daily_decr30'])

# %%
df_new.corr()
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001915  0.086376      0.205070
# msisdn                0.001915  1.000000 -0.002056     -0.001162
# aon                   0.086376 -0.002056  1.000000      0.083415
# daily_decr30          0.205070 -0.001162  0.083415      1.000000
# daily_decr90          0.236279 -0.001770  0.090119      0.972635
# rental30              0.095907 -0.001822  0.065092      0.534191
# rental90              0.112969 -0.001054  0.072367      0.601322
# last_rech_date_ma     0.009533 -0.003894  0.037767      0.044662
# last_rech_date_da     0.027410 -0.000119  0.003322      0.065247
# last_rech_amt_ma      0.159589 -0.005122  0.081721      0.247894
# cnt_ma_rech30         0.292492 -0.001306  0.015264      0.402762
# fr_ma_rech30          0.244479 -0.001690  0.054315      0.243364
# sumamnt_ma_rech30     0.270259 -0.000321  0.056602      0.480381
# ...

# %%
sns.heatmap(df_new.corr(),annot=True,linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
df_new.corr()['label'].sort_values()
# Out:
# cnt_da_rech30           0.001266
# msisdn                  0.001915
# last_rech_date_ma       0.009533
# maxamnt_loans30         0.013150
# cnt_da_rech90           0.025171
# last_rech_date_da       0.027410
# medianamnt_loans90      0.029620
# medianamnt_loans30      0.040130
# aon                     0.086376
# maxamnt_loans90         0.088565
# rental30                0.095907
# rental90                0.112969
# fr_ma_rech90            0.125260
# pdate                   0.146505
# last_rech_amt_ma        0.159589
# medianamnt_ma_rech30    0.171223
# daily_decr30            0.205070
# payback30               0.224473
# medianmarechprebal30    0.228347
# payback90               0.233802
# daily_decr90            0.236279
# cnt_loans30             0.238983
# amnt_loans30            0.244307
# fr_ma_rech30            0.244479
# amnt_loans90            0.246878
# medianamnt_ma_rech90    0.250390
# last_rech_amt_ma        0.255552
# sumamnt_ma_rech30       0.270259
# ...

# %%
df_new.drop(['fr_da_rech30','fr_da_rech90'],axis=1,inplace=True)
df_new
# Out:
#         label  msisdn     aon  daily_decr30  daily_decr90   rental30  \
# 0           0   40191   272.0     55.272507      7.440685  14.836779
# 1           1  142291   712.0    110.099955     10.493448  60.755740
# 2           1   33594   535.0     37.389838      6.114723  30.002167
# 3           1  104157   241.0      4.607385      2.146482  12.626163
# 4           1    6910   947.0     12.272707      3.503242  33.149661
# ...       ...     ...     ...           ...           ...        ...
# 209588      1   42866   404.0     12.323649      3.510506  33.002879
# 209589      1  178248  1075.0      6.077499      2.465259  41.573549
# 209590      1   53995  1013.0    108.826062     10.445432  76.562589
# 209591      1  111388  1732.0    111.750742     10.589405  20.293595
# 209592      1  121263  1581.0     67.002701      8.206161  21.998182
#
#          rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# ...

# %%
df_new.isnull().sum()
# Out:
# label                      0
# msisdn                     0
# aon                        0
# daily_decr30            1693
# daily_decr90            1693
# rental30                4089
# rental90                4294
# last_rech_date_ma       1052
# last_rech_date_da          9
# last_rech_amt_ma           0
# cnt_ma_rech30              0
# fr_ma_rech30               0
# sumamnt_ma_rech30          0
# medianamnt_ma_rech30       0
# medianmarechprebal30    1300
# cnt_ma_rech90              0
# fr_ma_rech90               0
# sumamnt_ma_rech90          0
# medianamnt_ma_rech90       0
# medianmarechprebal90    1351
# cnt_da_rech30              0
# cnt_da_rech90              0
# cnt_loans30                0
# amnt_loans30               0
# maxamnt_loans30            0
# medianamnt_loans30         0
# cnt_loans90                0
# amnt_loans90               0
# maxamnt_loans90            0
# medianamnt_loans90         0
# payback30                  0
# payback90                  0
# ...

# %%
df_new.dropna(inplace=True)

# %%
df_new.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# cnt_da_rech90           0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# last_rech_amt_ma        0
# dtype: int64

# %%
df_new.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'cnt_da_rech90', 'cnt_loans30', 'amnt_loans30', 'maxamnt_loans30',
#        'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90', 'maxamnt_loans90',
#        'medianamnt_loans90', 'payback30', 'payback90', 'pdate',
#        'last_rech_amt_ma '],
#       dtype='object')

# %%
x=df_new.drop(["label"],axis=1)
x
# Out:
#         msisdn     aon  daily_decr30  daily_decr90   rental30   rental90  \
# 0        40191   272.0     55.272507      7.440685  14.836779  16.128546
# 1       142291   712.0    110.099955     10.493448  60.755740  60.755740
# 2        33594   535.0     37.389838      6.114723  30.002167  30.002167
# 3       104157   241.0      4.607385      2.146482  12.626163  12.626163
# 4         6910   947.0     12.272707      3.503242  33.149661  33.149661
# ...        ...     ...           ...           ...        ...        ...
# 209588   42866   404.0     12.323649      3.510506  33.002879  33.002879
# 209589  178248  1075.0      6.077499      2.465259  41.573549  41.573549
# 209590   53995  1013.0    108.826062     10.445432  76.562589  94.303765
# 209591  111388  1732.0    111.750742     10.589405  20.293595  31.378018
# 209592  121263  1581.0     67.002701      8.206161  21.998182  25.123694
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
y=df_new.iloc[:,0]
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 153089, dtype: int64

# %%
x.value_counts
# Out:
# <bound method DataFrame.value_counts of         msisdn     aon  daily_decr30  daily_decr90   rental30   rental90  \
# 0        40191   272.0     55.272507      7.440685  14.836779  16.128546
# 1       142291   712.0    110.099955     10.493448  60.755740  60.755740
# 2        33594   535.0     37.389838      6.114723  30.002167  30.002167
# 3       104157   241.0      4.607385      2.146482  12.626163  12.626163
# 4         6910   947.0     12.272707      3.503242  33.149661  33.149661
# ...        ...     ...           ...           ...        ...        ...
# 209588   42866   404.0     12.323649      3.510506  33.002879  33.002879
# 209589  178248  1075.0      6.077499      2.465259  41.573549  41.573549
# 209590   53995  1013.0    108.826062     10.445432  76.562589  94.303765
# 209591  111388  1732.0    111.750742     10.589405  20.293595  31.378018
# 209592  121263  1581.0     67.002701      8.206161  21.998182  25.123694
#
# ...

# %%
y.value_counts()
# Out:
# 1    132773
# 0     20316
# Name: label, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
dfx=sc.fit_transform(x)
dfx
# Out:
# array([[-0.98275361, -0.74989904,  0.23913229, ...,  3.12519954,
#          0.6044929 ,  0.12497221],
#        [ 0.91488863,  0.14033762,  1.49733964, ..., -0.92348028,
#          1.57292171,  1.9980835 ],
#        [-1.1053662 , -0.21778031, -0.17124802, ..., -0.92348028,
#          1.98796264,  0.12497221],
#        ...,
#        [-0.72619089,  0.74934043,  1.46810571, ...,  0.54850249,
#          1.01953382,  0.12497221],
#        [ 0.34052195,  2.20406805,  1.53522272, ...,  1.51269809,
#          0.83507119, -0.45600331],
#        [ 0.52405983,  1.89855502,  0.50832259, ..., -0.92348028,
#          0.00498934,  2.5410792 ]])

# %%
from imblearn import under_sampling, over_sampling

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
dfx,dfy=smt.fit_resample(x,y)

# %%
dfy.value_counts()
# Out:
# 0    132773
# 1    132773
# Name: label, dtype: int64

# %%
dfx.value_counts()
# Out:
# msisdn  aon         daily_decr30  daily_decr90  rental30   rental90   last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  cnt_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  payback90  pdate  last_rech_amt_ma
# ...

# %%
dfx
# Out:
#         msisdn         aon  daily_decr30  daily_decr90   rental30   rental90  \
# 0        40191  272.000000     55.272507      7.440685  14.836779  16.128546
# 1       142291  712.000000    110.099955     10.493448  60.755740  60.755740
# 2        33594  535.000000     37.389838      6.114723  30.002167  30.002167
# 3       104157  241.000000      4.607385      2.146482  12.626163  12.626163
# 4         6910  947.000000     12.272707      3.503242  33.149661  33.149661
# ...        ...         ...           ...           ...        ...        ...
# 265541  131393  253.881221      0.000000      0.000000   2.886115   2.886115
# 265542  122662  518.339669     54.190627      7.371812  66.599872  70.189676
# 265543   10575  556.449507     65.617675      8.099912  28.824502  35.587828
# 265544  125097  373.542613      2.000901      1.414205   8.834712   8.834712
# 265545   40262  311.016358      0.366741      0.466085   5.377411   5.377411
#
# ...

# %%
dfy
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 265541    0
# 265542    0
# 265543    0
# 265544    0
# 265545    0
# Name: label, Length: 265546, dtype: int64

# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
x_train,x_test,y_train,y_test=train_test_split(dfx,dfy,test_size=.30,random_state=45)

# %%
rf=RandomForestClassifier(n_estimators=300,random_state=42)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.943788913436433
# [[37472  2533]
#  [ 1945 37714]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     40005
#            1       0.94      0.95      0.94     39659
#
#     accuracy                           0.94     79664
#    macro avg       0.94      0.94      0.94     79664
# weighted avg       0.94      0.94      0.94     79664

# %%
predrf=rf.predict(x_test)
from sklearn.model_selection import cross_val_score
rfs=accuracy_score(y_test,predrf)
for j in range(4,7):
    rfscore=cross_val_score(rf,dfx,dfy,cv=j)
    rfcv=rfscore.mean()
    print('at cv:-',j)
    print('crossvalidation score:',rfcv*100)
    print('accuracy_score is:-',rfs*100)
    print('\n')
# Out:
# at cv:- 4
# crossvalidation score: 93.53937258174234
# accuracy_score is:- 94.3788913436433
#
#
# at cv:- 5
# crossvalidation score: 93.58910641809159
# accuracy_score is:- 94.3788913436433
#
#
# at cv:- 6
# crossvalidation score: 93.65234835928119
# accuracy_score is:- 94.3788913436433

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
#ad=AdaBoostClassifier(base_estimator=DecisionTreeClassifier,n_estimators=50,learning_rate=1.0)
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# 0.887502510544286
# [[35952  4053]
#  [ 4909 34750]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     40005
#            1       0.90      0.88      0.89     39659
#
#     accuracy                           0.89     79664
#    macro avg       0.89      0.89      0.89     79664
# weighted avg       0.89      0.89      0.89     79664

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
print(accuracy_score(y_test,predgb))
print(confusion_matrix(y_test,predgb))
print(classification_report(y_test,predgb))
# Out:
# 0.9122062663185379
# [[36856  3149]
#  [ 3845 35814]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91     40005
#            1       0.92      0.90      0.91     39659
#
#     accuracy                           0.91     79664
#    macro avg       0.91      0.91      0.91     79664
# weighted avg       0.91      0.91      0.91     79664

# %% [markdown]
# randomForestClassifier working well we will continue with that

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
from sklearn.model_selection import GridSearchCV
parameters={'max_features':['auto','sqrt','log2'],
            'max_depth':[4,5,6,7,8],
            'criterion':['gini','entropy'],
            'n_estimators':[100,200,300,400,500]}

# %%
gcv=GridSearchCV(estimator=RandomForestClassifier(),
                 param_grid= parameters,
                 cv=6,
                 scoring="accuracy")

# %%
#gcv.fit(x_train,y_train)
#gcv.best_params_

# %%
#gcv.best_score_

# %%
#gcv_pred=gcv.best_estimator_.predict(x_test)
#accuracy_score(y_test,gcv_pred)

# %% [markdown]
# auc roc curve

# %%
#from sklearn.metrics import plot_roc_curve
#plot_roc_curve(gcv.best_estimator_,x_test,y_test)
#plt.title("AUC ROC PLOT")
#plt.show()

# %% [markdown]
# saving the best model

# %%
#import joblib

# %%
#joblib.dump(rf,'rffile.obj')
